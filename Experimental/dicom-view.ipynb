# %% [markdown]
# # View Digital Imaging and Communications in Medicine (DICOM) for Chest X-rays

# %%
from fastai.basics import *
from fastai.callback.all import *
from fastai.vision.all import *
from fastai.medical.imaging import *
import pydicom
import pandas as pd

# %%
path = Path('/home/jupyter/data/mimic-cxr-dcm')
train_imgs = path/'files'

# %%
items = get_dicom_files(train_imgs)

# %%
patient = 7
dicom = items[patient].dcmread()

# %%
dicom.show()

# %%
data_scaled = dicom.hist_scaled()
plt.imshow(data_scaled, cmap=plt.cm.bone);

# %%
data_scaled = dicom.hist_scaled()
plt.imshow(data_scaled, cmap=plt.cm.gist_rainbow);
